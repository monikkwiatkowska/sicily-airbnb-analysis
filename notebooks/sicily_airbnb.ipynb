# %%
# exploratory data analysis

# %%
# importing libraries and reading the file (from google drive)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

listings = pd.read_csv ('/content/drive/MyDrive/Portfolio Projects/listing.gz')

# %%
# converting to df and checking first 5 rows

df = pd.DataFrame (listings)
df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   7011   https://www.airbnb.com/rooms/7011  20250929042425   2025-09-29
# 1  22948  https://www.airbnb.com/rooms/22948  20250929042425   2025-09-30
# 2  35264  https://www.airbnb.com/rooms/35264  20250929042425   2025-09-29
# 3  43992  https://www.airbnb.com/rooms/43992  20250929042425   2025-09-30
# 4  43995  https://www.airbnb.com/rooms/43995  20250929042425   2025-09-30
#
#         source                                               name  \
# 0  city scrape               SEASIDE - Historic Antique Residence
# 1  city scrape  BnB Room with Balcony near  Valley of the Temples
# 2  city scrape                         Etna-sea a panoramic villa
# 3  city scrape                             Two steps from the sea
# 4  city scrape                                    Villa Verdemare
#
#                                          description  \
# 0  WINEYARD WITH COLOURS OF THE SEASIDE.<br /><br...
# 1  Near the Central Station and the beginning of ...
# 2  Our country house, swathed in the greenery of ...
# 3  Very nice flat in front of the beach with a wo...
# 4  Wonderful villa that can easily accommodate up...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  The neighborhood is in a residential area, cen...
# 2  Contact with nature, relaxation, remarkable pa...
# 3                                                NaN
# 4                                                NaN
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...    16888  ...
# 1  https://a0.muscache.com/pictures/hosting/Hosti...    88837  ...
# 2  https://a0.muscache.com/pictures/7dc73c6a-7bee...   151644  ...
# 3  https://a0.muscache.com/pictures/9495798/e9cfb...   192525  ...
# 4  https://a0.muscache.com/pictures/9498289/eef27...   192525  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.72                   4.59                4.59
# 1                        4.83                   4.90                4.86
# 2                        4.82                   4.85                4.77
# 3                        4.95                   4.56                4.66
# 4                        4.93                   4.72                4.72
#
#               license instant_bookable calculated_host_listings_count  \
# 0  IT081011A1HJT5H6NW                t                             10
# 1  IT084001C1KUVGVHF9                t                              3
# 2  IT087035B5VYN4LFLN                f                              5
# 3  IT081008C26PNHNIA6                f                              2
# 4  IT081020C2NSGROBUN                f                              2
#
#   calculated_host_listings_count_entire_homes  \
# 0                                          10
# 1                                           0
# 2                                           5
# 3                                           2
# 4                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            3
# 2                                            0
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.16
# 1                                           0              2.67
# 2                                           0              0.89
# 3                                           0              0.53
# 4                                           0              0.46
#
# [5 rows x 79 columns]

# %%
# data types and info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57531 entries, 0 to 57530
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            57531 non-null  int64
#  1   listing_url                                   57531 non-null  object
#  2   scrape_id                                     57531 non-null  int64
#  3   last_scraped                                  57531 non-null  object
#  4   source                                        57531 non-null  object
#  5   name                                          57531 non-null  object
#  6   description                                   55811 non-null  object
#  7   neighborhood_overview                         23086 non-null  object
#  8   picture_url                                   57531 non-null  object
#  9   host_id                                       57531 non-null  int64
#  10  host_url                                      57531 non-null  object
#  11  host_name                                     57473 non-null  object
#  12  host_since                                    57473 non-null  object
#  13  host_location                                 37062 non-null  object
#  14  host_about                                    22168 non-null  object
#  15  host_response_time                            42570 non-null  object
#  16  host_response_rate                            42570 non-null  object
#  17  host_acceptance_rate                          45903 non-null  object
#  18  host_is_superhost                             56370 non-null  object
#  19  host_thumbnail_url                            57473 non-null  object
#  20  host_picture_url                              57473 non-null  object
#  21  host_neighbourhood                            2171 non-null   object
#  22  host_listings_count                           57473 non-null  float64
#  23  host_total_listings_count                     57473 non-null  float64
#  24  host_verifications                            57473 non-null  object
#  25  host_has_profile_pic                          57473 non-null  object
#  26  host_identity_verified                        57473 non-null  object
#  27  neighbourhood                                 23087 non-null  object
#  28  neighbourhood_cleansed                        57531 non-null  object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      57531 non-null  float64
#  31  longitude                                     57531 non-null  float64
#  32  property_type                                 57531 non-null  object
#  33  room_type                                     57531 non-null  object
#  34  accommodates                                  57531 non-null  int64
#  35  bathrooms                                     51860 non-null  float64
#  36  bathrooms_text                                57475 non-null  object
#  37  bedrooms                                      56553 non-null  float64
#  38  beds                                          51861 non-null  float64
#  39  amenities                                     57531 non-null  object
#  40  price                                         51889 non-null  object
#  41  minimum_nights                                57531 non-null  int64
#  42  maximum_nights                                57531 non-null  int64
#  43  minimum_minimum_nights                        57526 non-null  float64
#  44  maximum_minimum_nights                        57526 non-null  float64
#  45  minimum_maximum_nights                        57526 non-null  float64
#  46  maximum_maximum_nights                        57526 non-null  float64
#  47  minimum_nights_avg_ntm                        57531 non-null  float64
#  48  maximum_nights_avg_ntm                        57531 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              56086 non-null  object
#  51  availability_30                               57531 non-null  int64
#  52  availability_60                               57531 non-null  int64
#  53  availability_90                               57531 non-null  int64
#  54  availability_365                              57531 non-null  int64
#  55  calendar_last_scraped                         57531 non-null  object
#  56  number_of_reviews                             57531 non-null  int64
#  57  number_of_reviews_ltm                         57531 non-null  int64
#  58  number_of_reviews_l30d                        57531 non-null  int64
#  59  availability_eoy                              57531 non-null  int64
#  60  number_of_reviews_ly                          57531 non-null  int64
#  61  estimated_occupancy_l365d                     57531 non-null  int64
#  62  estimated_revenue_l365d                       51889 non-null  float64
#  63  first_review                                  41591 non-null  object
#  64  last_review                                   41591 non-null  object
#  65  review_scores_rating                          41591 non-null  float64
#  66  review_scores_accuracy                        41588 non-null  float64
#  67  review_scores_cleanliness                     41589 non-null  float64
#  68  review_scores_checkin                         41583 non-null  float64
#  69  review_scores_communication                   41584 non-null  float64
#  70  review_scores_location                        41584 non-null  float64
#  71  review_scores_value                           41582 non-null  float64
#  72  license                                       48531 non-null  object
#  73  instant_bookable                              57531 non-null  object
#  74  calculated_host_listings_count                57531 non-null  int64
#  75  calculated_host_listings_count_entire_homes   57531 non-null  int64
#  76  calculated_host_listings_count_private_rooms  57531 non-null  int64
#  77  calculated_host_listings_count_shared_rooms   57531 non-null  int64
#  78  reviews_per_month                             41591 non-null  float64
# dtypes: float64(24), int64(20), object(35)
# memory usage: 34.7+ MB

# %%
# names of the columns

df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'availability_eoy',
#        'number_of_reviews_ly', 'estimated_occupancy_l365d',
#        'estimated_revenue_l365d', 'first_review', 'last_review',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
# searching for missing values

df.isnull().any()
# Out:
# id                                              False
# listing_url                                     False
# scrape_id                                       False
# last_scraped                                    False
# source                                          False
#                                                 ...
# calculated_host_listings_count                  False
# calculated_host_listings_count_entire_homes     False
# calculated_host_listings_count_private_rooms    False
# calculated_host_listings_count_shared_rooms     False
# reviews_per_month                                True
# Length: 79, dtype: bool

# %%
# statistics

df.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  5.753100e+04  5.753100e+04  5.753100e+04         57473.000000
# mean   6.575658e+17  2.025093e+13  2.786940e+08            47.302733
# std    5.859217e+17  6.511775e+00  2.321915e+08           184.288770
# min    7.011000e+03  2.025093e+13  1.688800e+04             1.000000
# 25%    3.362695e+07  2.025093e+13  5.010769e+07             1.000000
# 50%    7.904431e+17  2.025093e+13  2.123032e+08             3.000000
# 75%    1.196481e+18  2.025093e+13  4.965379e+08             6.000000
# max    1.519680e+18  2.025093e+13  7.209809e+08          2745.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed      latitude  \
# count               57473.000000                           0.0  57531.000000
# mean                   81.751744                           NaN     37.640145
# std                   334.360216                           NaN      0.538620
# min                     1.000000                           NaN     35.494560
# 25%                     1.000000                           NaN     37.238505
# 50%                     3.000000                           NaN     37.802940
# 75%                     7.000000                           NaN     38.105191
# max                  8775.000000                           NaN     38.810240
#
#           longitude  accommodates     bathrooms  ...  \
# count  57531.000000  57531.000000  51860.000000  ...
# mean      14.138333      4.358259      1.416014  ...
# std        1.024592      2.318357      1.013893  ...
# min       11.928847      1.000000      0.000000  ...
# 25%       13.327149      3.000000      1.000000  ...
# 50%       14.515280      4.000000      1.000000  ...
# 75%       15.097030      5.000000      2.000000  ...
# max       15.651680     16.000000    100.000000  ...
#
#        review_scores_cleanliness  review_scores_checkin  \
# count               41589.000000           41583.000000
# mean                    4.782011               4.833510
# std                     0.397011               0.359178
# min                     0.000000               0.000000
# 25%                     4.730000               4.820000
# 50%                     4.920000               4.950000
# 75%                     5.000000               5.000000
# max                     5.000000               5.000000
#
#        review_scores_communication  review_scores_location  \
# count                 41584.000000            41584.000000
# mean                      4.839677                4.711867
# std                       0.372714                0.410044
# min                       0.000000                0.000000
# 25%                       4.840000                4.600000
# 50%                       4.980000                4.830000
# 75%                       5.000000                5.000000
# max                       5.000000                5.000000
#
#        review_scores_value  calculated_host_listings_count  \
# count         41582.000000                    57531.000000
# mean              4.679183                       12.808625
# std               0.456595                       37.588231
# min               0.000000                        1.000000
# 25%               4.580000                        1.000000
# 50%               4.800000                        2.000000
# 75%               5.000000                        5.000000
# max               5.000000                      291.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                 57531.000000
# mean                                     11.136413
# std                                      34.747716
# min                                       0.000000
# 25%                                       1.000000
# 50%                                       2.000000
# 75%                                       4.000000
# max                                     277.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                  57531.000000
# mean                                       1.632250
# std                                        4.823123
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        1.000000
# max                                       50.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                 57531.000000       41591.000000
# mean                                      0.016721           0.787285
# std                                       0.402882           1.058523
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.130000
# 50%                                       0.000000           0.400000
# 75%                                       0.000000           1.000000
# max                                      19.000000          12.830000
#
# [8 rows x 44 columns]

# %%
# count of properties in neighbourhoods
df['neighbourhood_cleansed'].nunique()

# top 5 count
df['neighbourhood_cleansed'].value_counts().head()
# Out:
# neighbourhood_cleansed
# Palermo                    7935
# Catania                    4662
# Siracusa                   3865
# Noto                       1833
# Castellammare del Golfo    1710
# Name: count, dtype: int64

# %%
# property types

df['property_type'].value_counts()
# Out:
# property_type
# Entire rental unit                    18722
# Entire home                           10934
# Entire condo                           4741
# Private room in bed and breakfast      4724
# Entire villa                           4676
#                                       ...
# Private room in island                    1
# Private room in barn                      1
# Shared room in hotel                      1
# Shared room in houseboat                  1
# Private room in religious building        1
# Name: count, Length: 99, dtype: int64

# %%
# room type

df['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    45943
# Private room       11261
# Hotel room           259
# Shared room           68
# Name: count, dtype: int64

# %%
# example of 10 pricings per unit per night

df['price'].head(10)
# Out:
# 0    $219.00
# 1     $45.00
# 2    $109.00
# 3     $68.00
# 4     $75.00
# 5    $137.00
# 6     $41.00
# 7     $43.00
# 8    $102.00
# 9    $300.00
# Name: price, dtype: object

# %%
# barplot for unit type

df['room_type'].value_counts().plot(kind='bar')
plt.title('listings by room type')
plt.show()

# %%
# summary of EDA

print("Total listings:", len(df))
print("Total columns:", len(df.columns))
print("")
print("Neighborhoods:", df['neighbourhood_cleansed'].nunique())
print("Property types:", df['property_type'].nunique())
print("")
print("Most common neighborhood:", df['neighbourhood_cleansed'].value_counts().index[0])
print("Most common property type:", df['property_type'].value_counts().index[0])
# Out:
# Total listings: 57531
# Total columns: 79
#
# Neighborhoods: 371
# Property types: 99
#
# Most common neighborhood: Palermo
# Most common property type: Entire rental unit
